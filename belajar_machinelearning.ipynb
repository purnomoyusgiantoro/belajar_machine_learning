# %% [markdown]
# <a href="https://colab.research.google.com/github/purnomoyusgiantoro/belajar_machine_learning/blob/main/belajar_machinelearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/london_merged.xls')

# %%
df.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
df.shape
# Out:
# (17414, 10)

# %%
df.describe()
# Out:
#                 cnt            t1            t2           hum    wind_speed  \
# count  17414.000000  17414.000000  17414.000000  17414.000000  17414.000000
# mean    1143.101642     12.468091     11.520836     72.324954     15.913063
# std     1085.108068      5.571818      6.615145     14.313186      7.894570
# min        0.000000     -1.500000     -6.000000     20.500000      0.000000
# 25%      257.000000      8.000000      6.000000     63.000000     10.000000
# 50%      844.000000     12.500000     12.500000     74.500000     15.000000
# 75%     1671.750000     16.000000     16.000000     83.000000     20.500000
# max     7860.000000     34.000000     34.000000    100.000000     56.500000
#
#        weather_code    is_holiday    is_weekend        season
# count  17414.000000  17414.000000  17414.000000  17414.000000
# mean       2.722752      0.022051      0.285403      1.492075
# std        2.341163      0.146854      0.451619      1.118911
# ...

# %%
df['is_holiday'].value_counts()
# Out:
# is_holiday
# 0.0    17030
# 1.0      384
# Name: count, dtype: int64

# %%
df['is_weekend'].value_counts()
# Out:
# is_weekend
# 0.0    12444
# 1.0     4970
# Name: count, dtype: int64

# %%
df['season'].value_counts()
# Out:
# season
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: count, dtype: int64

# %%
df['season'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='season'>

# %%
print(df.columns)
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
print(f'timestamp : {df.timestamp.isnull().sum()}')
print(f'cnt : {df.cnt.isnull().sum()}')
print(f't1 : {df.t1.isnull().sum()}')
print(f't2 : {df.t2.isnull().sum()}')
print(f'hum : {df.hum.isnull().sum()}')
print(f'wind_speed : {df.wind_speed.isnull().sum()}')
print(f'weather_code : {df.weather_code.isnull().sum()}')
# Out:
# timestamp : 0
# cnt : 0
# t1 : 0
# t2 : 0
# hum : 0
# wind_speed : 0
# weather_code : 0
